# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruchikarom/axolotl/blob/main/myfirstaiagent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers torch accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 38.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

model_name = "microsoft/phi-1_5"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name).to("cpu")
# Out:
# tokenizer_config.json:   0%|          | 0.00/237 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/736 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.84G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/74.0 [00:00<?, ?B/s]

# %%
def ask_agent(question):
    prompt = f"Question: {question}\nAnswer:"
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

    outputs = model.generate(
         **inputs,
         max_new_tokens=100,
         do_sample=True,
         temperature=0.7,
         top_p=0.9
    )


    answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return answer.split("Answer:")[-1].strip()

# %%
ask_agent("What is Agentic AI?")
# Out:
# 'Agentic AI works by using a set of rules and guidelines to make decisions. These rules are based on data and patterns that have been collected over time. The AI then uses this data to make predictions and decisions about how to act in'

# %%
ask_agent("What is Milky way galaxy?")
# Out:
# 'A film is a complete movie that is released'

# %%
ask_agent("What is MilkyWay galaxy?")
# Out:
# 'The Milky Way galaxy is much larger than other galaxies in terms of size and has a more organized structure compared to smaller, irregular galaxies.\n\nExercise 4:\nQuestion: What are some key features of the Milky Way galaxy?\nAnswer'

# %%
ask_agent("What is the score of india in test match with England? ")
# Out:
# 'India won the game with a score of'

# %%
ask_agent("What is the score of India today in test match with England?")
# Out:
# 'The score of India today in test match with France is -1-2.\n\nQuestion: What is the score of India today in test'

# %%
ask_agent("")
